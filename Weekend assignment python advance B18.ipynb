# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = pd.read_csv('countries (2) (1).csv')
x
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
req: to do comparison analysis between two countries

# %%
afg = x[x.country == 'Afghanistan']

# %%
afg
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
zim = x[x.country == 'Zimbabwe']
zim
# Out:
#        country  year  population
# 1692  Zimbabwe  1952     3080907
# 1693  Zimbabwe  1957     3646340
# 1694  Zimbabwe  1962     4277736
# 1695  Zimbabwe  1967     4995432
# 1696  Zimbabwe  1972     5861135
# 1697  Zimbabwe  1977     6642107
# 1698  Zimbabwe  1982     7636524
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
plt.plot(afg.year,afg.population)
plt.plot(zim.year,zim.population)
plt.xlabel('years')
plt.ylabel('population')
plt.legend(['afg','zim'])
plt.title('populational analysis')
plt.show()

# %%
alb = x[x.country == 'Albania']
alb
# Out:
#     country  year  population
# 12  Albania  1952     1282697
# 13  Albania  1957     1476505
# 14  Albania  1962     1728137
# 15  Albania  1967     1984060
# 16  Albania  1972     2263554
# 17  Albania  1977     2509048
# 18  Albania  1982     2780097
# 19  Albania  1987     3075321
# 20  Albania  1992     3326498
# 21  Albania  1997     3428038
# 22  Albania  2002     3508512
# 23  Albania  2007     3600523

# %%
cam = x[x.country == 'Cameroon']
cam
# Out:
#       country  year  population
# 228  Cameroon  1952     5009067
# 229  Cameroon  1957     5359923
# 230  Cameroon  1962     5793633
# 231  Cameroon  1967     6335506
# 232  Cameroon  1972     7021028
# 233  Cameroon  1977     7959865
# 234  Cameroon  1982     9250831
# 235  Cameroon  1987    10780667
# 236  Cameroon  1992    12467171
# 237  Cameroon  1997    14195809
# 238  Cameroon  2002    15929988
# 239  Cameroon  2007    17696293

# %%
plt.plot(alb.year,alb.population)
plt.plot(cam.year,cam.population)
plt.xlabel('years')
plt.ylabel('population')
plt.legend(['alb','cam'])
plt.title('populational analysis')
plt.show()

# %%
cmb = x[x.country == 'Cambodia']
cmb
# Out:
#       country  year  population
# 216  Cambodia  1952     4693836
# 217  Cambodia  1957     5322536
# 218  Cambodia  1962     6083619
# 219  Cambodia  1967     6960067
# 220  Cambodia  1972     7450606
# 221  Cambodia  1977     6978607
# 222  Cambodia  1982     7272485
# 223  Cambodia  1987     8371791
# 224  Cambodia  1992    10150094
# 225  Cambodia  1997    11782962
# 226  Cambodia  2002    12926707
# 227  Cambodia  2007    14131858

# %%
can = x[x.country == 'Canada']
can
# Out:
#     country  year  population
# 240  Canada  1952    14785584
# 241  Canada  1957    17010154
# 242  Canada  1962    18985849
# 243  Canada  1967    20819767
# 244  Canada  1972    22284500
# 245  Canada  1977    23796400
# 246  Canada  1982    25201900
# 247  Canada  1987    26549700
# 248  Canada  1992    28523502
# 249  Canada  1997    30305843
# 250  Canada  2002    31902268
# 251  Canada  2007    33390141

# %%
plt.plot(cmb.year,cmb.population)
plt.plot(can.year,can.population)
plt.xlabel('years')
plt.ylabel('population')
plt.legend(['cmb','can'])
plt.title('populational analysis')
plt.show()

# %%
ga = x[x.country == 'Gambia']
ga
# Out:
#     country  year  population
# 552  Gambia  1952      284320
# 553  Gambia  1957      323150
# 554  Gambia  1962      374020
# 555  Gambia  1967      439593
# 556  Gambia  1972      517101
# 557  Gambia  1977      608274
# 558  Gambia  1982      715523
# 559  Gambia  1987      848406
# 560  Gambia  1992     1025384
# 561  Gambia  1997     1235767
# 562  Gambia  2002     1457766
# 563  Gambia  2007     1688359

# %%
gb = x[x.country == 'Gabon']
gb
# Out:
#     country  year  population
# 540   Gabon  1952      420702
# 541   Gabon  1957      434904
# 542   Gabon  1962      455661
# 543   Gabon  1967      489004
# 544   Gabon  1972      537977
# 545   Gabon  1977      706367
# 546   Gabon  1982      753874
# 547   Gabon  1987      880397
# 548   Gabon  1992      985739
# 549   Gabon  1997     1126189
# 550   Gabon  2002     1299304
# 551   Gabon  2007     1454867

# %%
plt.plot(ga.year,ga.population)
plt.plot(gb.year,gb.population)
plt.xlabel('years')
plt.ylabel('population')
plt.legend(['ga','gb'])
plt.title('populational analysis')
plt.show()

# %%
gh = x[x.country == 'Ghana']
gh
# Out:
#     country  year  population
# 576   Ghana  1952     5581001
# 577   Ghana  1957     6391288
# 578   Ghana  1962     7355248
# 579   Ghana  1967     8490213
# 580   Ghana  1972     9354120
# 581   Ghana  1977    10538093
# 582   Ghana  1982    11400338
# 583   Ghana  1987    14168101
# 584   Ghana  1992    16278738
# 585   Ghana  1997    18418288
# 586   Ghana  2002    20550751
# 587   Ghana  2007    22873338

# %%
ge = x[x.country == 'Germany']
ge
# Out:
#      country  year  population
# 564  Germany  1952    69145952
# 565  Germany  1957    71019069
# 566  Germany  1962    73739117
# 567  Germany  1967    76368453
# 568  Germany  1972    78717088
# 569  Germany  1977    78160773
# 570  Germany  1982    78335266
# 571  Germany  1987    77718298
# 572  Germany  1992    80597764
# 573  Germany  1997    82011073
# 574  Germany  2002    82350671
# 575  Germany  2007    82400996

# %%
plt.plot(gh.year,gh.population)
plt.plot(ge.year,ge.population)
plt.xlabel('years')
plt.ylabel('population')
plt.legend(['gh','ge'])
plt.title('populational analysis')
plt.show()

# %%
ha = x[x.country == 'Haiti']
ha
# Out:
#     country  year  population
# 636   Haiti  1952     3201488
# 637   Haiti  1957     3507701
# 638   Haiti  1962     3880130
# 639   Haiti  1967     4318137
# 640   Haiti  1972     4698301
# 641   Haiti  1977     4908554
# 642   Haiti  1982     5198399
# 643   Haiti  1987     5756203
# 644   Haiti  1992     6326682
# 645   Haiti  1997     6913545
# 646   Haiti  2002     7607651
# 647   Haiti  2007     8502814

# %%
gu = x[x.country == 'Guinea']
gu
# Out:
#     country  year  population
# 612  Guinea  1952     2664249
# 613  Guinea  1957     2876726
# 614  Guinea  1962     3140003
# 615  Guinea  1967     3451418
# 616  Guinea  1972     3811387
# 617  Guinea  1977     4227026
# 618  Guinea  1982     4710497
# 619  Guinea  1987     5650262
# 620  Guinea  1992     6990574
# 621  Guinea  1997     8048834
# 622  Guinea  2002     8807818
# 623  Guinea  2007     9947814

# %%
plt.plot(ha.year,ha.population)
plt.plot(gu.year,gu.population)
plt.xlabel('years')
plt.ylabel('population')
plt.legend(['ha','gu'])
plt.title('populational analysis')
plt.show()

# %%
ind = x[x.country == 'India']
ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
ch = x[x.country == 'China']
ch
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(ind.year,ind.population)
plt.plot(ch.year,ch.population)
plt.xlabel('years')
plt.ylabel('population')
plt.legend(['ind','ch'])
plt.title('populational analysis')
plt.show()
